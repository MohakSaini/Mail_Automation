# %%
import Database_manager as db


conn = db.DatabaseManager('postgres', 'password')


# conn.connect_to_database('daily_updates')


# conn.create_database('daily_updates')

columns = {
    'id': 'SERIAL PRIMARY KEY',
    'title': 'VARCHAR(100) NOT NULL',
    'description': 'TEXT',
    'created_at': 'DATE DEFAULT CURRENT_DATE'
}


# conn.create_table('Daily_update', columns)

update = {
    'title': 'Initial Setup',
    'description': 'Enviroment Setup and Project folder structured and base code ready',
}

# conn.insert_data('daily_update', update)

# conn.show_data('Daily_update')

# # conn.drop_table('daily_updates')
# conn.describe_table('daily_update')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import Database_manager as db
#       4 conn = db.DatabaseManager('postgres', 'password')
#       7 # conn.connect_to_database('daily_updates')
#       8
#       9
#      10 # conn.create_database('daily_updates')
#
# File ~/Documents/Send_Mail/Postgresql/Database_manager.py:1
# ----> 1 import psycopg2
#       2 from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT
#       5 class DatabaseManager:
#
# ModuleNotFoundError: No module named 'psycopg2'

# %%
conn.list_databases()
